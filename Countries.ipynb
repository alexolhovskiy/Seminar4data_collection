# %%
import pandas as pd
file=pd.read_csv("countries.csv")
file
# Out:
#                    Country Population, total  \
# 0              Afghanistan        42,239,854
# 1                  Albania         2,745,972
# 2                  Algeria        45,606,480
# 3           American Samoa            43,914
# 4                  Andorra            80,088
# ..                     ...               ...
# 212  Virgin Islands (U.S.)           104,917
# 213     West Bank and Gaza         5,165,775
# 214            Yemen, Rep.        34,449,825
# 215                 Zambia        20,569,737
# 216               Zimbabwe        16,665,409
#
#      Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)  \
# 0                                                  NaN
# 1                                                  0.0
# 2                                                  0.5
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 25 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   Country                                                                              217 non-null    object
#  1   Population, total                                                                    217 non-null    object
#  2   Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)                  164 non-null    float64
#  3   GDP growth (annual %)                                                                214 non-null    float64
#  4   GDP (current US$)                                                                    214 non-null    object
# ...

# %%
file.describe()
# Out:
#        Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)  \
# count                                         164.000000
# mean                                           10.968293
# std                                            18.113818
# min                                             0.000000
# 25%                                             0.200000
# 50%                                             1.300000
# 75%                                            15.625000
# max                                            80.700000
#
#        GDP growth (annual %)  \
# count             214.000000
# mean                3.070561
# std                 6.996352
# min               -29.700000
# 25%                 0.925000
# 50%                 2.950000
# 75%                 5.000000
# max                80.500000
#
#        Statistical performance indicators (SPI): Overall score (scale 0-100)  \
# count                                         186.000000
# ...
